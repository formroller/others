# %%
import pandas as pd
import numpy as np

from konlpy.tag import Okt
from collections import Counter

import csv

# %%
df = pd.read_csv('pt_1228_1.csv', encoding='cp949')

# %%
np.where('안전상비' in df['info'],'의료기기',df['info'])
# Out:
# array(['해운대구 의료기기 판매업 현황', '해운대구 안전상비 의약품 판매업 현황', '해운대구 약국 현황', ...,
#        '무더위심터 표준데이터', '건강증진센터 표준데이터', '치매센터 표준데이터'], dtype=object)

# %%
okt = Okt()
test = []
for i in df['tag']:
    test.append(i)

# %%
Counter(test)
# Out:
# Counter({'의료기기': 18,
#          '안전상비': 2,
#          '약국': 25,
#          '치과기공소': 26,
#          '의료기관': 62,
#          '안경업소': 25,
#          '의료유사업소': 1,
#          '의약품도매상': 5,
#          '폐의약품': 2,
#          '안경업소현황': 12,
#          '병원및요양원현황': 1,
#          '공중위생업': 14,
#          '거래처목록': 1,
#          '의약품목록': 2,
#          '세탁업소': 1,
#          '소독업소': 18,
#          '장애인시설': 1,
#          '장례식장현황': 4,
#          '공중위생서비스': 3,
#          '어린이': 1,
#          '휴일의료기관안내': 1,
#          '동물병원현황': 7,
#          '건강증진': 1,
#          '흡연시설': 4,
#          '담배소매인지정현황': 3,
#          '산후조리원현황': 10,
#          '지정현황': 1,
#          '의료영상정보': 1,
#          '세균': 1,
#          '의료급여대상자현황': 2,
#          '금연아파트': 3,
#          '원숭이)': 1,
#          '머리)': 1,
#          '전신)': 1,
#          '가정내불용의약품처리현황': 1,
#          '라이브러리': 2,
#          '진단용방사선발생장치및특수의료장비현황': 2,
#          '엔테로바이러스': 1,
#          '위암': 17,
#          '관내': 1,
#          '반려동물': 1,
#          '희귀': 1,
# ...
